# %%
# %run ugafl.py

# %%
# %run main.py --num_rounds 30
# Out:
# UGAFL: creating 3 clients...
# 	client 0, dataset size=50 initial solution= slope: -0.60393 bias: -0.31706
# 	client 1, dataset size=30 initial solution= slope:  0.07903 bias: -0.34405
# 	client 2, dataset size=80 initial solution= slope:  0.36542 bias: -0.99110
#
# UGAFL: Round 0 started
# [0] client 0 (slope:  0.09779 bias: -0.32744)
# [0] client 1 (slope:  0.12652 bias: -0.34688)
# [0] client 2 (slope:  0.97723 bias: -0.98356)
# UGAFL: Round 0 completed, server (slope:  0.36718 bias: -0.55263)
#
# UGAFL: Round 1 started
# [1] client 0 (slope:  0.56292 bias: -0.27275)
# [1] client 1 (slope:  0.14175 bias: -0.31991)
# [1] client 2 (slope:  1.51249 bias: -0.99469)
# UGAFL: Round 1 completed, server (slope:  0.86145 bias: -0.71333)
#
# UGAFL: Round 2 started
# [2] client 0 (slope:  0.82173 bias: -0.16196)
# [2] client 1 (slope:  0.13485 bias: -0.27413)
# [2] client 2 (slope:  1.93475 bias: -1.03831)
# UGAFL: Round 2 completed, server (slope:  1.25092 bias: -0.72924)
#
# ...
